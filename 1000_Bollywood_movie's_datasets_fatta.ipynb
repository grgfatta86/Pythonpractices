# %% [markdown]
# <a href="https://colab.research.google.com/github/grgfatta86/Pythonpractices/blob/main/1000_Bollywood_movie's_datasets_fatta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = '/Top 1000 Bollywood Movies and their boxoffice.csv'
df = pd.read_csv(path)
df
# Out:
#      Unnamed: 0    SN                       Movie    Worldwide   India Net  \
# 0             0     1                     Pathaan  10500000000  5240000000
# 1             1     2  Baahubali 2 The Conclusion  17880000000  5100000000
# 2             2     3               KGF Chapter 2  12080000000  4350000000
# 3             3     4                      Dangal  20700000000  3740000000
# 4             4     5                       Sanju   5880000000  3420000000
# ..          ...   ...                         ...          ...         ...
# 995         995   996                     Nikamma            0    20000000
# 996         996   997                    Saugandh     30000000    20000000
# 997         997   998                 Akaash Vani     30000000    20000000
# 998         998   999                     Zwigato     10000000    20000000
# 999         999  1000                      FryDay     20000000    20000000
#
#      India Gross     Overseas      Budget               Verdict
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'SN', 'Movie', 'Worldwide', 'India Net', 'India Gross',
#        'Overseas', 'Budget', 'Verdict'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.size
# Out:
# 9000

# %%
df.head()
# Out:
#    Unnamed: 0  SN                       Movie    Worldwide   India Net  \
# 0           0   1                     Pathaan  10500000000  5240000000
# 1           1   2  Baahubali 2 The Conclusion  17880000000  5100000000
# 2           2   3               KGF Chapter 2  12080000000  4350000000
# 3           3   4                      Dangal  20700000000  3740000000
# 4           4   5                       Sanju   5880000000  3420000000
#
#    India Gross     Overseas      Budget               Verdict
# 0   6570000000   3920000000  2500000000  All Time Blockbuster
# 1  14160000000   3710000000  2500000000  All Time Blockbuster
# 2  10000000000   2070000000  1000000000  All Time Blockbuster
# 3   5350000000  15350000000   700000000  All Time Blockbuster
# 4   4380000000   1500000000  1000000000  All Time Blockbuster

# %%
df.head(4)
# Out:
#    Unnamed: 0  SN                       Movie    Worldwide   India Net  \
# 0           0   1                     Pathaan  10500000000  5240000000
# 1           1   2  Baahubali 2 The Conclusion  17880000000  5100000000
# 2           2   3               KGF Chapter 2  12080000000  4350000000
# 3           3   4                      Dangal  20700000000  3740000000
#
#    India Gross     Overseas      Budget               Verdict
# 0   6570000000   3920000000  2500000000  All Time Blockbuster
# 1  14160000000   3710000000  2500000000  All Time Blockbuster
# 2  10000000000   2070000000  1000000000  All Time Blockbuster
# 3   5350000000  15350000000   700000000  All Time Blockbuster

# %%
df.tail()
# Out:
#      Unnamed: 0    SN        Movie  Worldwide  India Net  India Gross  \
# 995         995   996      Nikamma          0   20000000     20000000
# 996         996   997     Saugandh   30000000   20000000     30000000
# 997         997   998  Akaash Vani   30000000   20000000     20000000
# 998         998   999      Zwigato   10000000   20000000     10000000
# 999         999  1000       FryDay   20000000   20000000     20000000
#
#      Overseas     Budget   Verdict
# 995         0   10000000         0
# 996         0   20000000   Average
# 997         0  100000000  Disaster
# 998         0   10000000         0
# 999         0  150000000  Disaster

# %%
df.tail(2)
# Out:
#      Unnamed: 0    SN    Movie  Worldwide  India Net  India Gross  Overseas  \
# 998         998   999  Zwigato   10000000   20000000     10000000         0
# 999         999  1000   FryDay   20000000   20000000     20000000         0
#
#         Budget   Verdict
# 998   10000000         0
# 999  150000000  Disaster

# %%
df[['SN','Movie','Budget']]
# Out:
#        SN                       Movie      Budget
# 0       1                     Pathaan  2500000000
# 1       2  Baahubali 2 The Conclusion  2500000000
# 2       3               KGF Chapter 2  1000000000
# 3       4                      Dangal   700000000
# 4       5                       Sanju  1000000000
# ..    ...                         ...         ...
# 995   996                     Nikamma    10000000
# 996   997                    Saugandh    20000000
# 997   998                 Akaash Vani   100000000
# 998   999                     Zwigato    10000000
# 999  1000                      FryDay   150000000
#
# [1000 rows x 3 columns]

# %%
df[df.columns[2:5]]
# Out:
#                           Movie    Worldwide   India Net
# 0                       Pathaan  10500000000  5240000000
# 1    Baahubali 2 The Conclusion  17880000000  5100000000
# 2                 KGF Chapter 2  12080000000  4350000000
# 3                        Dangal  20700000000  3740000000
# 4                         Sanju   5880000000  3420000000
# ..                          ...          ...         ...
# 995                     Nikamma            0    20000000
# 996                    Saugandh     30000000    20000000
# 997                 Akaash Vani     30000000    20000000
# 998                     Zwigato     10000000    20000000
# 999                      FryDay     20000000    20000000
#
# [1000 rows x 3 columns]

# %%
df.iloc[0:4,:3]
# Out:
#    Unnamed: 0  SN                       Movie
# 0           0   1                     Pathaan
# 1           1   2  Baahubali 2 The Conclusion
# 2           2   3               KGF Chapter 2
# 3           3   4                      Dangal

# %%
df.iloc[0:4]
# Out:
#    Unnamed: 0  SN                       Movie    Worldwide   India Net  \
# 0           0   1                     Pathaan  10500000000  5240000000
# 1           1   2  Baahubali 2 The Conclusion  17880000000  5100000000
# 2           2   3               KGF Chapter 2  12080000000  4350000000
# 3           3   4                      Dangal  20700000000  3740000000
#
#    India Gross     Overseas      Budget               Verdict
# 0   6570000000   3920000000  2500000000  All Time Blockbuster
# 1  14160000000   3710000000  2500000000  All Time Blockbuster
# 2  10000000000   2070000000  1000000000  All Time Blockbuster
# 3   5350000000  15350000000   700000000  All Time Blockbuster

# %%
df.isnull()
# Out:
#      Unnamed: 0     SN  Movie  Worldwide  India Net  India Gross  Overseas  \
# 0         False  False  False      False      False        False     False
# 1         False  False  False      False      False        False     False
# 2         False  False  False      False      False        False     False
# 3         False  False  False      False      False        False     False
# 4         False  False  False      False      False        False     False
# ..          ...    ...    ...        ...        ...          ...       ...
# 995       False  False  False      False      False        False     False
# 996       False  False  False      False      False        False     False
# 997       False  False  False      False      False        False     False
# 998       False  False  False      False      False        False     False
# 999       False  False  False      False      False        False     False
#
#      Budget  Verdict
# 0     False    False
# 1     False    False
# ...

# %%
df.Budget.sum()
# Out:
# 588900000000

# %%
df.Overseas.mean()
# Out:
# 971430000.0

# %%
df.Budget.mode()
# Out:
# 0    10000000
# Name: Budget, dtype: int64

# %%
df.empty
# Out:
# False

# %%
df.iat

# %%
df.ndim
# Out:
# 2

# %%
df_cp=df.copy
df_cp
# Out:
# <bound method NDFrame.copy of      Unnamed: 0    SN                       Movie    Worldwide   India Net  \
# 0             0     1                     Pathaan  10500000000  5240000000
# 1             1     2  Baahubali 2 The Conclusion  17880000000  5100000000
# 2             2     3               KGF Chapter 2  12080000000  4350000000
# 3             3     4                      Dangal  20700000000  3740000000
# 4             4     5                       Sanju   5880000000  3420000000
# ..          ...   ...                         ...          ...         ...
# 995         995   996                     Nikamma            0    20000000
# 996         996   997                    Saugandh     30000000    20000000
# 997         997   998                 Akaash Vani     30000000    20000000
# 998         998   999                     Zwigato     10000000    20000000
# 999         999  1000                      FryDay     20000000    20000000
#
# ...

# %%
df.Movie
# Out:
# 0                         Pathaan
# 1      Baahubali 2 The Conclusion
# 2                   KGF Chapter 2
# 3                          Dangal
# 4                           Sanju
#                   ...
# 995                       Nikamma
# 996                      Saugandh
# 997                   Akaash Vani
# 998                       Zwigato
# 999                        FryDay
# Name: Movie, Length: 1000, dtype: object

# %%
df.describe(include = "all") # Notice is only the numeric column'
# Out:
#          Unnamed: 0           SN         Movie     Worldwide     India Net  \
# count   1000.000000  1000.000000          1000  1.000000e+03  1.000000e+03
# unique          NaN          NaN           994           NaN           NaN
# top             NaN          NaN  Love Aaj Kal           NaN           NaN
# freq            NaN          NaN             2           NaN           NaN
# mean     499.500000   500.500000           NaN  1.832870e+09  4.079600e+08
# std      288.819436   288.819436           NaN  1.049006e+10  5.783055e+08
# min        0.000000     1.000000           NaN  0.000000e+00  2.000000e+07
# 25%      249.750000   250.750000           NaN  1.600000e+08  9.000000e+07
# 50%      499.500000   500.500000           NaN  3.700000e+08  2.000000e+08
# 75%      749.250000   750.250000           NaN  9.025000e+08  4.600000e+08
# max      999.000000  1000.000000           NaN  1.897000e+11  5.240000e+09
#
#          India Gross      Overseas        Budget Verdict
# ...

# %%
df
# Out:
#      Unnamed: 0    SN                       Movie    Worldwide   India Net  \
# 0             0     1                     Pathaan  10500000000  5240000000
# 1             1     2  Baahubali 2 The Conclusion  17880000000  5100000000
# 2             2     3               KGF Chapter 2  12080000000  4350000000
# 3             3     4                      Dangal  20700000000  3740000000
# 4             4     5                       Sanju   5880000000  3420000000
# ..          ...   ...                         ...          ...         ...
# 995         995   996                     Nikamma            0    20000000
# 996         996   997                    Saugandh     30000000    20000000
# 997         997   998                 Akaash Vani     30000000    20000000
# 998         998   999                     Zwigato     10000000    20000000
# 999         999  1000                      FryDay     20000000    20000000
#
#      India Gross     Overseas      Budget               Verdict
# ...

# %%
df.Worldwide.describe()
# Out:
# count    1.000000e+03
# mean     1.832870e+09
# std      1.049006e+10
# min      0.000000e+00
# 25%      1.600000e+08
# 50%      3.700000e+08
# 75%      9.025000e+08
# max      1.897000e+11
# Name: Worldwide, dtype: float64

# %%
df

# %%
df
